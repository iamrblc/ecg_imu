# %% [markdown]
# # POLAR H10 BELT DATA STREAM

# %% [markdown]
# ## Loads and imports

# %% [markdown]
# ### Packages

# %%
# Imports
# For bluetooth streaming
import asyncio
from bleak import BleakScanner      # This is for scanning available devices
from bleak import BleakClient       # This is for streaming

# Unix timestamping
import time
from datetime import datetime, timezone

# Data handling and data viz
import pandas as pd
import plotly.express as px

# Display real time measurements
from IPython.display import display

# %% [markdown]
# This is not something I understand 100%. The device address is clear. It's the device's unique identifier. The **HR_CHAR** (HR Measurement Characteristic) is something that should either show 180D (for Heart Rate Service, or 2a37 for heart rate measurement characteristic. It's in the first chunk's last few digits: 0000xxxx). But I probably don't really need to understand this perfectly, just be aware that these are heart rate sensor specific stuff.

# %% [markdown]
# ### Setups

# %%
# DEVICE_ADDRESS = "FFDB0E1C-0262-9016-D154-4562DABCBE43"  # THIS ONE IS FOR MAC ONLY
DEVICE_ADDRESS = "A0:9E:1A:E6:B0:5E"
HR_CHAR = "00002a37-0000-1000-8000-00805f9b34fb"
HEART_RATE_SERVICE_UUID = "0000180d-0000-1000-8000-00805f9b34fb"

stream_seconds = 60 # This is the default measurement length is seconds. Can be overwritten in params.

# %% [markdown]
# Address:     A0:9E:1A:E6:B0:5E
# Name:        Polar H10 E6B05E24
# RSSI:        -52 dBm
# Service UUIDs:
#   - 0000180d-0000-1000-8000-00805f9b34fb  [Heart Rate Service]
#   - 0000feee-0000-1000-8000-00805f9b34fb
# Manufacturer data:
#   - company_id=0x006B, data=33 1d 49 49
# TX power:    4 dBm
# ------------------------------------------------------------
# Address:     73:6A:07:35:44:C0
# Name:        <no name in advertisement>
# RSSI:        -100 dBm
# Manufacturer data:
#   - company_id=0x004C, data=09 08 13 04 c0 a8 00 9f 1b 58 16 08 00 f0 b6 93 01 86 d5 99

# %% [markdown]
# ## Looking for devices

# %%
def format_bytes(data: bytes) -> str:
    return data.hex(" ") if data else ""

async def scan_ble_devices(timeout: float = 8.0):
    results = await BleakScanner.discover(timeout=timeout, return_adv=True)

    if not results:
        print("No BLE devices found.")
        return {}

    print(f"Found {len(results)} BLE device(s).\n")
    for address, (device, adv) in results.items():
        display_name = adv.local_name or device.name or "<no name in advertisement>"
        print(f"Address:     {address}")
        print(f"Name:        {display_name}")
        print(f"RSSI:        {adv.rssi} dBm")       # Technically, signal strength.

        if adv.service_uuids:
            print("Service UUIDs:")
            for uuid in adv.service_uuids:
                marker = "  [Heart Rate Service]" if uuid.lower() == HEART_RATE_SERVICE_UUID else ""
                print(f"  - {uuid}{marker}")

        if adv.manufacturer_data:
            print("Manufacturer data:")
            for company_id, payload in adv.manufacturer_data.items():
                print(f"  - company_id=0x{company_id:04X}, data={format_bytes(payload)}")

        if adv.service_data:
            print("Service data:")
            for uuid, payload in adv.service_data.items():
                print(f"  - {uuid}: {format_bytes(payload)}")

        if adv.tx_power is not None:
            print(f"TX power:    {adv.tx_power} dBm")

        print("-" * 60)

    return results

scan_results = await scan_ble_devices(timeout=8.0)
# Out:
# Found 32 BLE device(s).
#
# Address:     EE:4F:0E:5A:A5:CD
# Name:        EV07BG_3513
# RSSI:        -88 dBm
# Manufacturer data:
#   - company_id=0x1234, data=00 04 05 18 20 44 00 00 a4 e7
# ------------------------------------------------------------
# Address:     16:02:91:01:6A:42
# Name:        <no name in advertisement>
# RSSI:        -88 dBm
# Manufacturer data:
#   - company_id=0x0006, data=01 09 20 22 bc 62 b9 f8 f2 90 7b 67 99 6d fb 56 36 21 3b e0 e5 2f d9 0c 1a ce 0e
# ------------------------------------------------------------
# Address:     26:AB:EB:EF:B7:47
# Name:        <no name in advertisement>
# RSSI:        -92 dBm
# Manufacturer data:
#   - company_id=0x0006, data=01 09 20 22 f3 95 a9 5d 06 f2 0c 72 ff cb 58 9c d3 1b ad 5b 6e 76 6e c6 69 77 84
# ------------------------------------------------------------
# Address:     00:C3:F4:EB:C6:3B
# Name:        <no name in advertisement>
# RSSI:        -86 dBm
# Manufacturer data:
#   - company_id=0x0075, data=42 04 01 80 60 00 c3 f4 eb c6 3b 02 c3 f4 eb c6 3a 01 89 ea 00 00 00 00
# ------------------------------------------------------------
# Address:     B0:99:D7:F5:FC:66
# Name:        Samsung CU7172 55
# RSSI:        -70 dBm
# Manufacturer data:
#   - company_id=0x0075, data=42 04 01 80 66 b0 99 d7 f5 fc 66 b2 99 d7 f5 fc 65 01 00 00 00 00 00 00
# ------------------------------------------------------------
# Address:     51:E8:96:F9:03:3D
# Name:        <no name in advertisement>
# RSSI:        -86 dBm
# Manufacturer data:
#   - company_id=0x004C, data=10 06 1f 1d 7e 89 af 68
# TX power:    17 dBm
# ------------------------------------------------------------
# Address:     56:7D:61:25:AC:3F
# Name:        <no name in advertisement>
# RSSI:        -98 dBm
# Manufacturer data:
#   - company_id=0x004C, data=10 07 31 1f a1 72 40 87 28
# TX power:    8 dBm
# ------------------------------------------------------------
# Address:     88:92:CC:5F:4A:28
# Name:        WH-CH720N
# RSSI:        -54 dBm
# Service UUIDs:
#   - 00000000-deca-fade-deca-deafdecacaff
#   - 00001108-0000-1000-8000-00805f9b34fb
#   - 0000110b-0000-1000-8000-00805f9b34fb
#   - 0000110c-0000-1000-8000-00805f9b34fb
#   - 0000110d-0000-1000-8000-00805f9b34fb
#   - 0000110e-0000-1000-8000-00805f9b34fb
#   - 0000111e-0000-1000-8000-00805f9b34fb
#   - 00001200-0000-1000-8000-00805f9b34fb
#   - 00001800-0000-1000-8000-00805f9b34fb
#   - 00001801-0000-1000-8000-00805f9b34fb
#   - 0000180a-0000-1000-8000-00805f9b34fb
#   - 0000fe03-0000-1000-8000-00805f9b34fb
#   - 0000fe2c-0000-1000-8000-00805f9b34fb
#   - 0000ff01-0000-1000-8000-00805f9b34ff
#   - 0000ff01-0000-1000-8000-504759592966
#   - 55f80aef-d89f-41a4-9e36-0ffc88dc81ce
#   - 5b833e05-6bc7-4802-8e9a-723ceca4bd8f
#   - 5b833e06-6bc7-4802-8e9a-723ceca4bd8f
#   - 5b833e0a-6bc7-4802-8e9a-723ceca4bd8f
#   - 67a846ad-de3e-451b-a6d8-7b2899ca2370
#   - 81c2e72a-0591-443e-a1ff-05f988593351
#   - 8901dfa8-5c7e-4d8f-9f0c-c2b70683f5f0
#   - 91c10d9c-aaef-42bd-b6d6-8a648c19213d
#   - 931c7e8a-540f-4686-b798-e8df0a2ad9f7
#   - 956c7b26-d49a-4ba8-b03f-b17d393cb6e2
#   - dc405470-a351-4a59-97d8-2e2e3b207fbb
#   - df21fe2c-2515-4fdb-8886-f12c4d67927c
#   - f8d1fbe4-7966-4334-8024-ff96c9330e15
#   - fa349b5f-8050-0030-0010-00001bbb231d
#   - fe59bfa8-7fe3-4a05-9d94-99fadc69faff
# Manufacturer data:
#   - company_id=0x5D2C, data=8c ad 65 6d d1 8e
# ------------------------------------------------------------
# Address:     4C:24:CE:EB:DE:F5
# Name:        MiTV-AFKR0
# RSSI:        -96 dBm
# Manufacturer data:
#   - company_id=0x038F, data=0a 10 42 0c 01 f4 de eb ce 24 4c ec
# ------------------------------------------------------------
# Address:     A0:9E:1A:E6:B0:5E
# Name:        Polar H10 E6B05E24
# RSSI:        -52 dBm
# Service UUIDs:
#   - 0000180d-0000-1000-8000-00805f9b34fb  [Heart Rate Service]
#   - 0000feee-0000-1000-8000-00805f9b34fb
# Manufacturer data:
#   - company_id=0x006B, data=33 1d 49 49
# TX power:    4 dBm
# ------------------------------------------------------------
# Address:     73:6A:07:35:44:C0
# Name:        <no name in advertisement>
# RSSI:        -100 dBm
# Manufacturer data:
#   - company_id=0x004C, data=09 08 13 04 c0 a8 00 9f 1b 58 16 08 00 f0 b6 93 01 86 d5 99
# ------------------------------------------------------------
# Address:     4C:24:CE:EC:18:1D
# Name:        <no name in advertisement>
# RSSI:        -80 dBm
# Manufacturer data:
#   - company_id=0x038F, data=0a 10 42 0c 01 1c 18 ec ce 24 4c ec
# ------------------------------------------------------------
# Address:     5B:13:17:7E:17:08
# Name:        <no name in advertisement>
# RSSI:        -100 dBm
# Manufacturer data:
#   - company_id=0x004C, data=10 06 47 1d ed 7f 3a 68
# TX power:    12 dBm
# ------------------------------------------------------------
# Address:     CE:FA:0A:71:7C:65
# Name:        <no name in advertisement>
# RSSI:        -54 dBm
# Service UUIDs:
#   - 0000fd82-0000-1000-8000-00805f9b34fb
#   - 0000fe2c-0000-1000-8000-00805f9b34fb
# Manufacturer data:
#   - company_id=0x012D, data=04 00 02 02 b0 31 08 01 ce d8 f1 fc 01 00 03 00 33 00 00 00
# Service data:
#   - 0000fe2c-0000-1000-8000-00805f9b34fb: 00 70 07 93 e7 90 40 07 42 11 4d 14 53
# TX power:    -12 dBm
# ------------------------------------------------------------
# Address:     1A:C5:39:E9:C3:F9
# Name:        <no name in advertisement>
# RSSI:        -92 dBm
# Manufacturer data:
#   - company_id=0x0006, data=01 09 20 22 da 30 f3 bd 69 27 2d 54 ba 75 5b 33 b1 78 a7 6d 47 9b 29 0f 65 e3 39
# ------------------------------------------------------------
# Address:     6D:DF:43:26:5F:34
# Name:        <no name in advertisement>
# RSSI:        -98 dBm
# Manufacturer data:
#   - company_id=0x004C, data=10 07 2c 1f 24 bd e1 aa 28
# TX power:    12 dBm
# ------------------------------------------------------------
# Address:     55:63:33:E0:57:96
# Name:        <no name in advertisement>
# RSSI:        -94 dBm
# Manufacturer data:
#   - company_id=0x004C, data=16 08 00 bf cd 04 aa b0 49 c0
# ------------------------------------------------------------
# Address:     17:E8:C7:DD:19:62
# Name:        <no name in advertisement>
# RSSI:        -92 dBm
# Manufacturer data:
#   - company_id=0x0006, data=01 09 20 22 87 ff e5 08 50 88 2b 39 44 c4 b0 bf a9 97 4f 16 eb a2 ae 7a eb fb 2a
# ------------------------------------------------------------
# Address:     E3:B9:27:5E:C1:A2
# Name:        <no name in advertisement>
# RSSI:        -54 dBm
# Manufacturer data:
#   - company_id=0x004C, data=12 02 00 02
# ------------------------------------------------------------
# Address:     74:19:0A:97:E4:84
# Name:        Galaxy Fit3 (E484)
# RSSI:        -94 dBm
# Service UUIDs:
#   - 0000180d-0000-1000-8000-00805f9b34fb  [Heart Rate Service]
# Manufacturer data:
#   - company_id=0x0075, data=01 00 02 00 01 02 ff 00 00 43 28 02 0a 97 e4 84
# ------------------------------------------------------------
# Address:     3D:F1:0C:4E:91:6C
# Name:        <no name in advertisement>
# RSSI:        -96 dBm
# Manufacturer data:
#   - company_id=0x0006, data=01 09 20 22 f1 95 9d 2d 63 1c cc 10 74 6b 47 4d 32 a0 a9 a6 6d 78 89 04 65 00 55
# ------------------------------------------------------------
# Address:     7D:78:60:CC:E7:C1
# Name:        <no name in advertisement>
# RSSI:        -98 dBm
# Manufacturer data:
#   - company_id=0x004C, data=10 05 0f 1c 7e 3d c9
# TX power:    17 dBm
# ------------------------------------------------------------
# Address:     C1:A9:9D:43:28:20
# Name:        <no name in advertisement>
# RSSI:        -92 dBm
# Manufacturer data:
#   - company_id=0x004C, data=12 02 00 00
# ------------------------------------------------------------
# Address:     21:2D:7C:AA:A8:EE
# Name:        <no name in advertisement>
# RSSI:        -96 dBm
# Manufacturer data:
#   - company_id=0x0006, data=01 0f 20 22 58 95 a8 98 70 6f 73 41 b6 4f 86 76 99 b1 16 f4 5d a5 25 cd 1b 0c c2
# ------------------------------------------------------------
# Address:     F4:FE:FB:69:43:93
# Name:        <no name in advertisement>
# RSSI:        -96 dBm
# Manufacturer data:
#   - company_id=0x0075, data=42 04 01 20 76 20 0f 00 02 01 32 01 01 00 01 00 00 00 00 00 00 00 00 00
# ------------------------------------------------------------
# Address:     EE:88:30:0F:F7:82
# Name:        <no name in advertisement>
# RSSI:        -86 dBm
# Manufacturer data:
#   - company_id=0x004C, data=12 02 00 00
# ------------------------------------------------------------
# Address:     E0:77:71:A8:FD:64
# Name:        <no name in advertisement>
# RSSI:        -102 dBm
# Service UUIDs:
#   - 24839ac4-8d7e-515c-aa42-267340cf2339
# ------------------------------------------------------------
# Address:     4C:C0:1E:B7:0C:72
# Name:        <no name in advertisement>
# RSSI:        -96 dBm
# ------------------------------------------------------------
# Address:     54:15:89:E1:DE:E3
# Name:        JBL PartyBox Encore
# RSSI:        -98 dBm
# Manufacturer data:
#   - company_id=0x0ECB, data=62 20 01 83 e4 00 00 20 00 00 00 54 15 89 e1 de e3 00 00 00 00 00 00 00
# ------------------------------------------------------------
# Address:     DC:45:CD:0B:CD:BB
# Name:        <no name in advertisement>
# RSSI:        -98 dBm
# Manufacturer data:
#   - company_id=0x004C, data=12 19 00 53 01 7c 44 ec d2 d4 aa 27 e7 d0 96 bc 61 cd 0b 5f df 73 f7 c7 6a 03 00
# ------------------------------------------------------------
# Address:     F1:0F:A2:1E:3A:2B
# Name:        <no name in advertisement>
# RSSI:        -96 dBm
# Manufacturer data:
#   - company_id=0x004C, data=12 02 00 03
# ------------------------------------------------------------
# Address:     49:8D:D8:77:23:55
# Name:        <no name in advertisement>
# RSSI:        -96 dBm
# Manufacturer data:
#   - company_id=0x004C, data=16 08 00 f3 c1 77 75 47 6d 62
# ------------------------------------------------------------

# %% [markdown]
# ## Connection test

# %%
device_address_to_check = DEVICE_ADDRESS
HEART_RATE_SERVICE_UUID = "0000180d-0000-1000-8000-00805f9b34fb"

async def check_device_access(device_address: str, timeout: float = 10.0):
    print(f"Looking for device {device_address}...")
    device = await BleakScanner.find_device_by_address(device_address, timeout=timeout)
    if device is None:
        print("Device not found. Make sure the belt is awake and advertising.")
        return False

    print(f"Found: {device.name} ({device.address})")
    print("Connecting...")

    async with BleakClient(device) as client:
        print(f"Connected: {client.is_connected}")

        if hasattr(client, "get_services"):
            services = await client.get_services()
        else:
            services = client.services

        if services is None:
            print("No services discovered.")
            return False

        service_list = list(services)
        print(f"Service count: {len(service_list)}")

        has_hr_service = any(
            s.uuid.lower() == HEART_RATE_SERVICE_UUID for s in service_list
        )
        print(f"Heart Rate service present: {has_hr_service}")

        print("\nGATT services and characteristics:")
        for service in service_list:
            print(f"[Service] {service.uuid}")
            for char in service.characteristics:
                props = ", ".join(char.properties)
                print(f"  - {char.uuid} ({props})")

    print("Disconnected.")
    return True

connected_ok = await check_device_access(device_address_to_check)
connected_ok
# Out:
# Looking for device A0:9E:1A:E6:B0:5E...
# Found: Polar H10 E6B05E24 (A0:9E:1A:E6:B0:5E)
# Connecting...
# Connected: True
# Service count: 7
# Heart Rate service present: True
#
# GATT services and characteristics:
# [Service] 6217ff4b-fb31-1140-ad5a-a45545d7ecf3
#   - 6217ff4c-c8ec-b1fb-1380-3ad986708e2d (read)
#   - 6217ff4d-91bb-91d0-7e2a-7cd3bda8a1f3 (write-without-response, indicate)
# [Service] 0000180d-0000-1000-8000-00805f9b34fb
#   - 00002a37-0000-1000-8000-00805f9b34fb (notify)
#   - 00002a38-0000-1000-8000-00805f9b34fb (read)
# [Service] fb005c80-02e7-f387-1cad-8acd2d8df0c8
#   - fb005c82-02e7-f387-1cad-8acd2d8df0c8 (notify)
#   - fb005c81-02e7-f387-1cad-8acd2d8df0c8 (read, write, indicate)
# [Service] 0000feee-0000-1000-8000-00805f9b34fb
#   - fb005c52-02e7-f387-1cad-8acd2d8df0c8 (notify)
#   - fb005c53-02e7-f387-1cad-8acd2d8df0c8 (write-without-response, write)
#   - fb005c51-02e7-f387-1cad-8acd2d8df0c8 (write-without-response, write, notify)
# [Service] 0000180f-0000-1000-8000-00805f9b34fb
#   - 00002a19-0000-1000-8000-00805f9b34fb (read, notify)
# [Service] 0000180a-0000-1000-8000-00805f9b34fb
#   - 00002a26-0000-1000-8000-00805f9b34fb (read)
#   - 00002a25-0000-1000-8000-00805f9b34fb (read)
#   - 00002a28-0000-1000-8000-00805f9b34fb (read)
#   - 00002a29-0000-1000-8000-00805f9b34fb (read)
#   - 00002a23-0000-1000-8000-00805f9b34fb (read)
#   - 00002a24-0000-1000-8000-00805f9b34fb (read)
#   - 00002a27-0000-1000-8000-00805f9b34fb (read)
# [Service] 00001801-0000-1000-8000-00805f9b34fb
#   - 00002a05-0000-1000-8000-00805f9b34fb (indicate)
# Disconnected.
# True

# %% [markdown]
# ## Streaming Heart Rate Data

# %% [markdown]
# In the byte array, the first one [0] is always some flag, the second [1] is the actual heart rate. The rest is all kinds of stuff. This was the same on the Decathlon device as well. I guess this is the standard.

# %% [markdown]
# ### Predefining functions

# %%
def parse_hr_measurement(data: bytearray) -> int:
    return data[1]  # The heart rate is the 2nd byte in the array

async def collect_hr(stream_seconds=stream_seconds):
    t_values = []
    hr_values = []

    live_handle = display("Waiting for connection...", display_id=True)

    def handle_hr(sender, data):
        hr = parse_hr_measurement(data)
        t_values.append(time.time())
        hr_values.append(hr)
        live_handle.update(f"HR: {hr} bpm")

    async with BleakClient(DEVICE_ADDRESS) as client:
        await client.start_notify(HR_CHAR, handle_hr)
        await asyncio.sleep(stream_seconds)
        await client.stop_notify(HR_CHAR)

        print("Data collection ended.")

    return pd.DataFrame({"timestamp": t_values, "hr": hr_values})

# %% [markdown]
# ### Streaming data

# %%
df = await collect_hr(120)
# Out:
# 'HR: 132 bpm'
# Data collection ended.

# %%
df.to_csv("hrtest.csv", index=False)

# %% [markdown]
# ## EDA

# %%
data = df.copy()
data.head()
# Out:
#       timestamp  hr
# 0  1.775139e+09  70
# 1  1.775139e+09  70
# 2  1.775139e+09  69
# 3  1.775139e+09  69
# 4  1.775139e+09  69

# %%
fig = px.line(data, x = "timestamp", y = "hr", title = "R peaks over time")
fig.show()

# %% [markdown]
# ## SANDBOX

# %%
data = pd.read_csv("hrtest.csv")

# %%
tmp = 1284101485
tmp = int(1.773847e+09)
print(datetime.fromtimestamp(tmp, tz=timezone.utc))
# Out:
# 2026-03-18 15:16:40+00:00

# %%
unix_tss = data["timestamp"].to_list()
unix_tss
# Out:
# [1773848803.988103,
#  1773848804.976962,
#  1773848805.983117,
#  1773848806.987401,
#  1773848807.978052,
#  1773848808.982191,
#  1773848809.987572,
#  1773848810.977584,
#  1773848811.982653,
#  1773848812.9876869,
#  1773848813.977961,
#  1773848814.98293,
#  1773848815.987217,
#  1773848816.977587,
#  1773848817.981795,
#  1773848818.987614,
#  1773848819.977563,
#  1773848820.9818828,
#  1773848821.988153,
#  1773848822.977194,
#  1773848823.982632,
#  1773848824.988158,
#  1773848825.977476,
#  1773848826.98292,
#  1773848827.987309,
#  1773848828.97717,
#  1773848829.982919,
#  1773848830.9865642,
#  1773848831.981722,
#  1773848833.593608,
#  1773848834.027771,
#  1773848835.333123,
#  1773848836.20278,
#  1773848837.072201,
#  1773848838.814442,
#  1773848839.248108,
#  1773848840.116479,
#  1773848840.992971,
#  1773848842.2964349,
#  1773848843.167569,
#  1773848844.039118,
#  1773848845.3427148,
#  1773848846.212778,
#  1773848847.0831392,
#  1773848848.388211,
#  1773848849.257664,
#  1773848850.127616,
#  1773848850.9977012,
#  1773848852.3036668,
#  1773848853.1730392,
#  1773848854.042036,
#  1773848855.347348,
#  1773848856.218165,
#  1773848857.087681,
#  1773848858.3930602,
#  1773848859.262625,
#  1773848860.132709,
#  1773848861.002103,
#  1773848862.307947,
#  1773848863.177691,
#  1773848864.0469718,
#  1773848865.352476,
#  1773848866.2226062,
#  1773848867.0912929,
#  1773848868.3976488,
#  1773848869.266978,
#  1773848870.137943,
#  1773848871.007623,
#  1773848872.31264,
#  1773848873.1819,
#  1773848874.052605,
#  1773848875.3573189,
#  1773848876.2275782,
#  1773848877.09746,
#  1773848878.4026198,
#  1773848879.272084,
#  1773848880.142696,
#  1773848881.882172,
#  1773848882.317492,
#  1773848883.1874409,
#  1773848884.056465,
#  1773848885.361633,
#  1773848886.232991,
#  1773848887.102216,
#  1773848888.410086,
#  1773848889.2784052,
#  1773848890.146534,
#  1773848891.017352,
#  1773848892.321662,
#  1773848893.192687,
#  1773848894.93242,
#  1773848895.367581,
#  1773848896.237477,
#  1773848897.1067688,
#  1773848897.976622,
#  1773848899.2817678,
#  1773848900.151836,
#  1773848901.022052,
#  1773848902.326782,
#  1773848903.196452,
#  1773848904.067522,
#  1773848905.371705,
#  1773848906.241686,
#  1773848907.112918,
#  1773848907.983197,
#  1773848909.287906,
#  1773848910.158922,
#  1773848911.0274491,
#  1773848912.332526,
#  1773848913.201579,
#  1773848914.07289,
#  1773848915.378913,
