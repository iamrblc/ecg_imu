# %%
import pandas as pd
import plotly.express as px

# %%
acc_data = pd.read_csv("acc_data_vox_mozgas.csv")
ecg_data = pd.read_csv("ecg_data_vox_mozgas.csv")

# %%
acc_data
# Out:
#              time        t_wall         t_device_ns    x    y    z
# 0        0.000000  1.776081e+09  599616561120366666 -435 -591 -715
# 1        0.005000  1.776081e+09  599616561120366666 -440 -588 -718
# 2        0.010000  1.776081e+09  599616561120366666 -445 -589 -717
# 3        0.015000  1.776081e+09  599616561120366666 -458 -587 -716
# 4        0.020000  1.776081e+09  599616561120366666 -462 -584 -717
# ...           ...           ...                 ...  ...  ...  ...
# 24547  120.114483  1.776082e+09  599616681079849664 -376 -789 -487
# 24548  120.119483  1.776082e+09  599616681079849664 -376 -785 -488
# 24549  120.124483  1.776082e+09  599616681079849664 -376 -785 -492
# 24550  120.129483  1.776082e+09  599616681079849664 -378 -787 -486
# 24551  120.134483  1.776082e+09  599616681079849664 -373 -786 -493
#
# [24552 rows x 6 columns]

# %%
px.line(acc_data,
        x = "time",
        y = ["x", "y", "z"],
        title = "Accelerometer data")

# %%
ecg_data
# Out:
#              time        t_wall         t_device_ns   ecg
# 0        0.000000  1.776081e+09  599616561584118212  7114
# 1        0.007692  1.776081e+09  599616561584118212  6485
# 2        0.015385  1.776081e+09  599616561584118212  7180
# 3        0.023077  1.776081e+09  599616561584118212  7084
# 4        0.030769  1.776081e+09  599616561584118212  6547
# ...           ...           ...                 ...   ...
# 15617  120.161053  1.776082e+09  599616681222094086   -43
# 15618  120.168745  1.776082e+09  599616681222094086   -45
# 15619  120.176437  1.776082e+09  599616681222094086   -41
# 15620  120.184130  1.776082e+09  599616681222094086   -43
# 15621  120.191822  1.776082e+09  599616681222094086   -38
#
# [15622 rows x 4 columns]

# %%
px.line(ecg_data,
        x = "time",
        y = "ecg",
        title = "ECG data (Vox + takony)")

# %% [markdown]
# # SANDBOX

# %%
import yaml

# %%
from datetime import datetime as dt
experiment_id = "test"
timestamp = dt.now().strftime("%y%m%d_%H%M")
filename = f"{experiment_id}_{timestamp}"
filename
# Out:
# 'test_260413_1401'

# %%
configfile = "/Users/rblc/create/work/elte/ecg_imu/scripts/config.yaml"
with open(configfile, "r") as f:
        data = yaml.safe_load(f)
# Out:
# ---------------------------------------------------------------------------
# ScannerError                              Traceback (most recent call last)
# Cell In[9], line 3
#       1 configfile = "/Users/rblc/create/work/elte/ecg_imu/scripts/config.yaml"
#       2 with open(configfile, "r") as f:
# ----> 3         data = yaml.safe_load(f)
#
# File ~/create/work/elte/ecg_imu/.venv/lib/python3.12/site-packages/yaml/__init__.py:125, in safe_load(stream)
#     117 def safe_load(stream):
#     118     """
#     119     Parse the first YAML document in a stream
#     120     and produce the corresponding Python object.
#    (...)    123     to be safe for untrusted input.
#     124     """
# --> 125     return load(stream, SafeLoader)
#
# File ~/create/work/elte/ecg_imu/.venv/lib/python3.12/site-packages/yaml/__init__.py:81, in load(stream, Loader)
#      79 loader = Loader(stream)
#      80 try:
# ---> 81     return loader.get_single_data()
#      82 finally:
# ...

# %%
data["experiment_id"]

# %%
from datetime import datetime as dt
experiment_id = data["experiment_id"]
timestamp = dt.now().strftime("%y%m%d_%H%M")
filename = f"{experiment_id}_{timestamp}"
filename

# %%
def config_reader(item):
    import yaml
    CONFIGPATH = "/Users/rblc/create/work/elte/ecg_imu/scripts/config.yaml"
    with open(CONFIGPATH, "r") as f:
        config_data = yaml.safe_load(f)
        return config_data[item]

# %%
config_data = config_reader("experiment_id")
config_data

# %%
def filename_generator() -> str:
    with open(configfile, "r") as f:
        data = yaml.safe_load(f)
        experiment_id = (data["experiment_id"])
        timestamp = dt.now().strftime("%y%m%d_%H%M")
        filename = f"{experiment_id}_{timestamp}"
        return filename

filename_generator()
