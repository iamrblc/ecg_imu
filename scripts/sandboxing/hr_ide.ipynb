# %%
import pandas as pd
import plotly.express as px

# %%
hr_data = pd.read_csv("hrtest.csv")
acc_data = pd.read_csv("acc_data.csv")
ecg_data = pd.read_csv("ecg_data.csv")

# %%
hr_data
# Out:
#         timestamp   hr
# 0    1.775139e+09   70
# 1    1.775139e+09   70
# 2    1.775139e+09   69
# 3    1.775139e+09   69
# 4    1.775139e+09   69
# ..            ...  ...
# 115  1.775139e+09  132
# 116  1.775139e+09  132
# 117  1.775139e+09  132
# 118  1.775139e+09  132
# 119  1.775139e+09  132
#
# [120 rows x 2 columns]

# %%
px.line(hr_data, y = "hr")

# %%
acc_data
# Out:
# Empty DataFrame
# Columns: [time, t_wall, t_device_ns, x, y, z]
# Index: []

# %%
px.line(acc_data,
        x = "time",
        y = ["x", "y", "z"],
        title = "Accelerometer data")

# %%
px.line(ecg_data,
        x = "time",
        y = "ecg",
        title = "ECG data")
